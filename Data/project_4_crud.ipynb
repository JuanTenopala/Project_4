# %%
import pandas as pd
from sqlalchemy import create_engine, text

# %%
conn_str = "postgresql+psycopg2://postgres:1234@localhost:5432/project_4"
engine = create_engine(conn_str)

# %%
query1 = f"""
SELECT *
FROM olympics
LIMIT 10;
;
"""

with engine.connect() as conn:
    result_query1 = pd.read_sql(text(query1), conn)

result_query1
# Out:
#        city  year     sport discipline           event  \
# 0  Montreal  1976  Aquatics     Diving  3m springboard
# 1  Montreal  1976  Aquatics     Diving  3m springboard
# 2  Montreal  1976  Aquatics     Diving  3m springboard
# 3  Montreal  1976  Aquatics     Diving  3m springboard
# 4  Montreal  1976  Aquatics     Diving    10m platform
# 5  Montreal  1976  Aquatics     Diving    10m platform
# 6  Montreal  1976  Aquatics     Diving    10m platform
# 7  Montreal  1976  Aquatics     Diving  3m springboard
# 8  Montreal  1976  Aquatics     Diving    10m platform
# 9  Montreal  1976  Aquatics     Diving    10m platform
#
#                      athlete gender country_code        country event_gender  \
# 0            KÖHLER, Christa  Women          GDR   East Germany            W
# 1        KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2       BOGGS, Philip George    Men          USA  United States            M
# 3   CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4     WILSON, Deborah Keplar  Women          USA  United States            W
# 5          LOUGANIS, Gregory    Men          USA  United States            M
# 6     VAYTSEKHOVSKAYA, Elena  Women          URS   Soviet Union            W
# 7  POTTER-MCINGVALE, Cynthia  Women          USA  United States            W
# 8             DIBIASI, Klaus    Men          ITA          Italy            M
# 9          ALEINIK, Vladimir    Men          URS   Soviet Union            M
#
#     medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze
# 5  Silver
# 6    Gold
# 7  Bronze
# 8    Gold
# 9  Bronze

# %%
query2 = f"""
SELECT COUNT(*)
FROM olympics
"""

with engine.connect() as conn:
    result_query2 = pd.read_sql(text(query2), conn)

result_query2
# Out:
#    count
# 0  15316

# %%
query3 = f"""
SELECT country, count(DISTINCT country_code)
FROM olympics
GROUP BY country
HAVING count(DISTINCT country_code) > 1
;
"""

with engine.connect() as conn:
    result_query3 = pd.read_sql(text(query3), conn)

result_query3
# Out:
# Empty DataFrame
# Columns: [country, count]
# Index: []

# %%
query4 = f"""
SELECT country, country_code
FROM olympics
WHERE country = 'Serbia'
;
"""

with engine.connect() as conn:
    result_query4 = pd.read_sql(text(query4), conn)

result_query4
# Out:
#    country country_code
# 0   Serbia          SRB
# 1   Serbia          SRB
# 2   Serbia          SRB
# 3   Serbia          SRB
# 4   Serbia          SRB
# 5   Serbia          SRB
# 6   Serbia          SRB
# 7   Serbia          SRB
# 8   Serbia          SRB
# 9   Serbia          SRB
# 10  Serbia          SRB
# 11  Serbia          SRB
# 12  Serbia          SRB
# 13  Serbia          SRB
# 14  Serbia          SRB
# 15  Serbia          SRB
# 16  Serbia          SRB
# 17  Serbia          SRB
# 18  Serbia          SRB
# 19  Serbia          SRB
# 20  Serbia          SRB
# 21  Serbia          SRB
# 22  Serbia          SRB
# 23  Serbia          SRB
# 24  Serbia          SRB
# 25  Serbia          SRB
# 26  Serbia          SRB
# 27  Serbia          SRB
# 28  Serbia          SRB

# %%
query5 = f"""
UPDATE olympics 
SET country_code = 'SRB'
WHERE country = 'Serbia'
;
"""

with engine.connect() as conn:
    #result_query5 = pd.read_sql(text(query5), conn)
    conn.execute(text(query5))
    conn.commit()

#result_query5

# %%
query6 = f"""
SELECT country, country_code
FROM olympics
WHERE country = 'Serbia'
;
"""

with engine.connect() as conn:
    result_query6 = pd.read_sql(text(query6), conn)

result_query6
# Out:
#    country country_code
# 0   Serbia          SRB
# 1   Serbia          SRB
# 2   Serbia          SRB
# 3   Serbia          SRB
# 4   Serbia          SRB
# 5   Serbia          SRB
# 6   Serbia          SRB
# 7   Serbia          SRB
# 8   Serbia          SRB
# 9   Serbia          SRB
# 10  Serbia          SRB
# 11  Serbia          SRB
# 12  Serbia          SRB
# 13  Serbia          SRB
# 14  Serbia          SRB
# 15  Serbia          SRB
# 16  Serbia          SRB
# 17  Serbia          SRB
# 18  Serbia          SRB
# 19  Serbia          SRB
# 20  Serbia          SRB
# 21  Serbia          SRB
# 22  Serbia          SRB
# 23  Serbia          SRB
# 24  Serbia          SRB
# 25  Serbia          SRB
# 26  Serbia          SRB
# 27  Serbia          SRB
# 28  Serbia          SRB

# %%
query7 = f"""
SELECT *
FROM olympics
;
"""

with engine.connect() as conn:
    result_query7 = pd.read_sql(text(query7), conn)

result_query7
# Out:
#            city  year     sport  discipline           event  \
# 0      Montreal  1976  Aquatics      Diving  3m springboard
# 1      Montreal  1976  Aquatics      Diving  3m springboard
# 2      Montreal  1976  Aquatics      Diving  3m springboard
# 3      Montreal  1976  Aquatics      Diving  3m springboard
# 4      Montreal  1976  Aquatics      Diving    10m platform
# ...         ...   ...       ...         ...             ...
# 15311   Beijing  2008  Aquatics  Water polo      water polo
# 15312   Beijing  2008  Aquatics  Water polo      water polo
# 15313   Beijing  2008  Aquatics  Water polo      water polo
# 15314   Beijing  2008  Aquatics  Water polo      water polo
# 15315   Beijing  2008    Tennis      Tennis         singles
#
#                         athlete gender country_code        country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# 1           KOSENKOV, Aleksandr    Men          URS   Soviet Union
# 2          BOGGS, Philip George    Men          USA  United States
# 3      CAGNOTTO, Giorgio Franco    Men          ITA          Italy
# 4        WILSON, Deborah Keplar  Women          USA  United States
# ...                         ...    ...          ...            ...
# 15311         CIRIC, Aleksandar    Men          SRB         Serbia
# 15312     VUJASINOVIC, Vladimir    Men          SRB         Serbia
# 15313           PEKOVIC, Branko    Men          SRB         Serbia
# 15314           UDOVICIC, Vanja    Men          SRB         Serbia
# 15315           DJOKOVIC, Novak    Men          SRB         Serbia
#
#       event_gender   medal
# 0                W  Silver
# 1                M  Bronze
# 2                M    Gold
# 3                M  Silver
# 4                W  Bronze
# ...            ...     ...
# 15311            M  Bronze
# 15312            M  Bronze
# 15313            M  Bronze
# 15314            M  Bronze
# 15315            M  Bronze
#
# [15316 rows x 11 columns]
